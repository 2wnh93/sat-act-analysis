# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Based on the SAT and ACT scores in 2017 and 2018, explore what affects participation rates and from analysis across states, provide recommmendations on how to improve SAT participation rates, in particular.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_17 = pd.read_csv("../data/sat_2017.csv")
act_17 = pd.read_csv("../data/act_2017.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_17.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_17.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0        21
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
# Understanding SAT 2017 dataset
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# Understanding ACT 2017 dataset
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
composite_mean = (act_17['English'].mean() + act_17['Math'].mean() + act_17['Reading'].mean() + act_17['Science'].mean()) / 4
composite_mean
# Out:
# 21.283653846153843

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# <u> SAT 2017 dataset </u>
#
# The SAT 2017 file contains 51 rows and 5 columns of SAT scores by US states. Data under columns "State" and "Participation" have an object datatype while data under columns "Evidence-Based Reading and Writing", "Math" and "Total" are integers.
#
# The mean SAT score for each section is as follows :
# - Evidence-Based Reading and Writing : 569.12
# - Math : 547.62.
#
# The total average SAT score is 1,126.10 while the minimum total SAT score is 950 and the maximum total SAT score is 1,295.
#
# Lowest SAT score for Evidence-Based Reading and Writing section is 482 while for Math is 52.
# Highest SAT score for Evidence-Based Reading and Writing section is 644 and for Math is 651.
#
# <u> ACT 2017 dataset </u>
#
# The ACT 2017 file contains 52 rows and 5 columns of ACT scores by US states. Data under columns "State", "Participation" and "Composite" are of object datatype while data under columns "English", "Math", "Reading" and "Science" are floats.
#
# The mean ACT score for each section is as follows:
# - English : 20.92
# - Math : 21.17
# - Reading : 22.00
# - Science : 21.04
#
# The Composite score (which is the average of the four tests, rounded to nearest whole number) can be derived and results to 21.
#
# Lowest ACT score for English section is 16.3, for Math is 18, for Reading is 18 and for Science is 2.3.
# Highest ACT score for English section is 25.5, for Math is 25.3, for Reading is 26 and for Science is 24.9.
# </font>

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# Yes, it looks complete because
#
# * SAT 2017 file has 51 entries and there are 51 non-null entries for each column.
# * ACT 2017 file has 52 entries and there are 52 non-null entries for each column.
#
# This implies that there are no NaN or N/A data in both datasets.
# </font>

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# <font color='darkblue'>
#
# The total SAT scores can only range from 400 to 1600 [^1] and the minimum and maximum SAT scores of the SAT17 dataset is within this range. Therefore, the SAT17 dataset appear to be reasonable. From the data source, there are some errors when recording the data from the webite to the csv file.
#
# ACT scores for each section can only range from 1 to 36 [^2] and so the minimum and maximum scores of the ACT17 dataset appear to be reasonable. However, the Composite score, which should be an average of the scores of every section (ie. English, Math, Reading and Science), seem to be computed erroneously.
#
#
# [^1]: https://blog.prepscholar.com/minimum-sat-score-for-college
# [^2]: http://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html
# </font>

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# For the SAT 2017 dataset, there is an error while populating the Math data for Maryland state. 
sat_17.loc[sat_17['State'] == 'Maryland', ['Math']] = 524

# check that Math data is corrected
sat_17.loc[sat_17['State'] == 'Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
# For the ACT 2017 dataset, there is a transcribing error for Wyoming's average Composite score and Maryland's average Science score
act_17.loc[act_17['State'] == 'Wyoming', ['Composite']] = 20.2
act_17.loc[act_17['State'] == 'Maryland', ['Science']] = 23.2

# check that scores are corrected
act_17.loc[(act_17['State'] == 'Wyoming') | (act_17['State'] == 'Maryland')]

# ACT 2017 scores used as reference
#https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6
# 51   Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
#
# For both the SAT2017 and ACT2017 dataset, the "Participation" data which is represented as percentages is currently recognised as an object datatype, when it would be more useful represented as a float eg. 60% = 0.60.
#
# Additionally for the ACT2017 dataset, the "Composite" scores are currently recognised as an object datatype when it should be a float datatype, since it is the average of the scores of the four sections (English, Math, Reading and Science). Object datatype is probably due to transcribing error which has been rectified above.
# </font>

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
def part_to_float(num):
    '''function changes participation rate to float decimal'''
    try:
        output = float(num.replace("%", ""))/ 100
    except:
        output = np.nan
    return output

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
def comp_to_float(num):
    '''function changes composite scores to float'''
    output = float(str(num))
    return output

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# Apply function on SAT17 dataset
sat_17['Participation'] = sat_17['Participation'].apply(part_to_float)

# Apply function on ACT17 dataset
act_17['Participation'] = act_17['Participation'].apply(part_to_float)
act_17['Composite'] = act_17['Composite'].apply(comp_to_float)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_17.rename(columns = {
    'State': 'state',
    'Participation': 'participation_sat_17',
    'Evidence-Based Reading and Writing': 'erw_sat_17',
    'Math': 'math_sat_17',
    'Total': 'total_sat_17'
}, inplace = True)

# %%
# check
sat_17.head()
# Out:
#         state  participation_sat_17  erw_sat_17  math_sat_17  total_sat_17
# 0     Alabama                  0.05         593          572          1165
# 1      Alaska                  0.38         547          533          1080
# 2     Arizona                  0.30         563          553          1116
# 3    Arkansas                  0.03         614          594          1208
# 4  California                  0.53         531          524          1055

# %%
act_17.rename(columns = {
    'State': 'state',
    'Participation': 'participation_act_17',
    'English': 'eng_act_17',
    'Math': 'math_act_17',
    'Reading': 'read_act_17',
    'Science': 'sci_act_17',
    'Composite': 'comp_act_17'
}, inplace = True)

# %%
# check
act_17.head()
# Out:
#       state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 0  National                  0.60        20.3         20.7         21.4
# 1   Alabama                  1.00        18.9         18.4         19.7
# 2    Alaska                  0.65        18.7         19.8         20.4
# 3   Arizona                  0.62        18.6         19.8         20.1
# 4  Arkansas                  1.00        18.9         19.0         19.7
#
#    sci_act_17  comp_act_17
# 0        21.0         21.0
# 1        19.4         19.2
# 2        19.9         19.8
# 3        19.8         19.7
# 4        19.5         19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# the ACT 2017 dataset contains the national average, when SAT 2017 did not. This row will be removed. 
act_17 = act_17.drop([0])
act_17.reset_index(drop = True, inplace = True)

# check index has been reset
act_17.head()
# Out:
#         state  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# 0     Alabama                  1.00        18.9         18.4         19.7
# 1      Alaska                  0.65        18.7         19.8         20.4
# 2     Arizona                  0.62        18.6         19.8         20.1
# 3    Arkansas                  1.00        18.9         19.0         19.7
# 4  California                  0.31        22.5         22.7         23.1
#
#    sci_act_17  comp_act_17
# 0        19.4         19.2
# 1        19.9         19.8
# 2        19.8         19.7
# 3        19.5         19.4
# 4        22.2         22.8

# %%
#check total entries 
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
# state                   51 non-null object
# participation_act_17    51 non-null float64
# eng_act_17              51 non-null float64
# math_act_17             51 non-null float64
# read_act_17             51 non-null float64
# sci_act_17              51 non-null float64
# comp_act_17             51 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
#check total entries
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                   51 non-null object
# participation_sat_17    51 non-null float64
# erw_sat_17              51 non-null int64
# math_sat_17             51 non-null int64
# total_sat_17            51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
comb_17 = pd.merge(sat_17, act_17, on = 'state')

# %%
# check on merge
comb_17.head()
# Out:
#         state  participation_sat_17  erw_sat_17  math_sat_17  total_sat_17  \
# 0     Alabama                  0.05         593          572          1165
# 1      Alaska                  0.38         547          533          1080
# 2     Arizona                  0.30         563          553          1116
# 3    Arkansas                  0.03         614          594          1208
# 4  California                  0.53         531          524          1055
#
#    participation_act_17  eng_act_17  math_act_17  read_act_17  sci_act_17  \
# 0                  1.00        18.9         18.4         19.7        19.4
# 1                  0.65        18.7         19.8         20.4        19.9
# 2                  0.62        18.6         19.8         20.1        19.8
# 3                  1.00        18.9         19.0         19.7        19.5
# 4                  0.31        22.5         22.7         23.1        22.2
#
#    comp_act_17
# 0         19.2
# 1         19.8
# 2         19.7
# ...

# %%
# check on merge
comb_17.shape
# Out:
# (51, 11)

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
comb_17.to_csv('../working_data/combined_17.csv', index = False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# read the ACT 2018 scores csv file using pandas
act_18 = pd.read_csv("../data/act_2018_updated.csv")
act_18.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
# determine the datatypes of columns to check if datatype is appropriate for analysis based on the nature of the data under the respective columns 
act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
# State                            51 non-null object
# Percentage of Students Tested    51 non-null int64
# Average Composite Score          51 non-null float64
# Average English Score            51 non-null float64
# Average Math Score               51 non-null float64
# Average Reading Score            51 non-null float64
# Average Science Score            51 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
# express percentage of students tested as a float in decimal form for consistency across datasets
act_18['Percentage of Students Tested'] = act_18['Percentage of Students Tested'] / 100

# check that data is converted accordingly
act_18['Percentage of Students Tested'].head()
# Out:
# 0    1.00
# 1    0.33
# 2    0.66
# 3    1.00
# 4    0.27
# Name: Percentage of Students Tested, dtype: float64

# %%
# compared against data source and correcting the data entry errors for Delaware and Georgia
# source : https://nces.ed.gov/programs/digest/d18/tables/dt18_226.60.asp
act_18.loc[act_18['State'] == 'Delaware', ['Average Composite Score']] = 23.8
act_18.loc[act_18['State'] == 'Georgia', ['Average Reading Score', 'Average Science Score']] = [22.1, 21.2]

# check that scores are corrected
act_18.loc[(act_18['State'] == 'Delaware') | (act_18['State'] == 'Georgia')]
# Out:
#        State  Percentage of Students Tested  Average Composite Score  \
# 7   Delaware                           0.17                     23.8
# 10   Georgia                           0.53                     21.4
#
#     Average English Score  Average Math Score  Average Reading Score  \
# 7                    23.7                23.1                   24.5
# 10                   20.9                20.7                   22.1
#
#     Average Science Score
# 7                    23.4
# 10                   21.2

# %%
# rename the columns as per rules stated above 
act_18.rename(columns = {
    'State': 'state',
    'Percentage of Students Tested': 'participation_act_18',
    'Average Composite Score': 'comp_act_18',
    'Average English Score': 'eng_act_18',
    'Average Math Score': 'math_act_18',
    'Average Reading Score': 'read_act_18',
    'Average Science Score': 'sci_act_18'
}, inplace = True)

# check
act_18.head(8)
# Out:
#          state  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0      Alabama                  1.00         19.1        18.9         18.3
# 1       Alaska                  0.33         20.8        19.8         20.6
# 2      Arizona                  0.66         19.2        18.2         19.4
# 3     Arkansas                  1.00         19.4        19.1         18.9
# 4   California                  0.27         22.7        22.5         22.5
# 5     Colorado                  0.30         23.9        23.9         23.2
# 6  Connecticut                  0.26         25.6        26.0         24.8
# 7     Delaware                  0.17         23.8        23.7         23.1
#
#    read_act_18  sci_act_18
# 0         19.6        19.0
# 1         21.6        20.7
# 2         19.5        19.2
# 3         19.7        19.4
# 4         23.0        22.1
# 5         24.4        23.5
# 6         26.1        24.9
# 7         24.5        23.4

# %%
# read the SAT 2018 scores csv file using pandas
sat_18 = pd.read_csv("../data/sat_2018.csv")
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# determine the datatypes of columns to check if datatype is appropriate for analysis based on the nature of the data under the respective columns 
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# convert participation rate into float using the function created above
sat_18['Participation'] = sat_18['Participation'].apply(part_to_float)

# check that datatype has changed
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# compared against data source and correcting the data entry errors for Florida, Hawaii, Indiana and Utah
# source : https://ipsr.ku.edu/ksdata/ksah/education/6ed16.pdf
sat_18.loc[sat_18['State'] == 'Florida'] = ['Florida', 0.97, 522, 493, 1014]
sat_18.loc[sat_18['State'] == 'Hawaii'] = ['Hawaii', 0.56, 550, 549, 1099]
sat_18.loc[sat_18['State'] == 'Indiana'] = ['Indiana', 0.67, 546, 539, 1086]
sat_18.loc[sat_18['State'] == 'Utah'] = ['Utah', 0.04, 618, 612, 1230]

# check that above data is updated accordingly
sat_18.loc[(sat_18['State'] == 'Florida') | (sat_18['State'] == 'Hawaii') | (sat_18['State'] == 'Indiana') | (sat_18['State'] == 'Utah')]
# Out:
#       State  Participation  Evidence-Based Reading and Writing  Math  Total
# 9   Florida           0.97                                 522   493   1014
# 11   Hawaii           0.56                                 550   549   1099
# 14  Indiana           0.67                                 546   539   1086
# 44     Utah           0.04                                 618   612   1230

# %%
# rename the columns as per rules stated above 
sat_18.rename(columns = {
    'State': 'state',
    'Participation': 'participation_sat_18',
    'Evidence-Based Reading and Writing': 'erw_sat_18',
    'Math': 'math_sat_18',
    'Total': 'total_sat_18'
}, inplace = True)

# check
sat_18.head()
# Out:
#         state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1169
# 4  California                  0.60         540          536          1076

# %%
act_18.head()
# Out:
#         state  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0     Alabama                  1.00         19.1        18.9         18.3
# 1      Alaska                  0.33         20.8        19.8         20.6
# 2     Arizona                  0.66         19.2        18.2         19.4
# 3    Arkansas                  1.00         19.4        19.1         18.9
# 4  California                  0.27         22.7        22.5         22.5
#
#    read_act_18  sci_act_18
# 0         19.6        19.0
# 1         21.6        20.7
# 2         19.5        19.2
# 3         19.7        19.4
# 4         23.0        22.1

# %%
# merge both 2018 SAT and ACT datasets
comb_18 = pd.merge(sat_18, act_18, on = 'state')

# check on merge
comb_18.head()
# Out:
#         state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1169
# 4  California                  0.60         540          536          1076
#
#    participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 0                  1.00         19.1        18.9         18.3         19.6
# 1                  0.33         20.8        19.8         20.6         21.6
# 2                  0.66         19.2        18.2         19.4         19.5
# 3                  1.00         19.4        19.1         18.9         19.7
# 4                  0.27         22.7        22.5         22.5         23.0
#
#    sci_act_18
# 0        19.0
# 1        20.7
# 2        19.2
# ...

# %%
# check on merge
comb_18.shape
# Out:
# (51, 11)

# %%
# save clean merged dataframe for 2018 SAT and ACT datasets
comb_18.to_csv('../working_data/combined_18.csv', index = False)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# merge both SAT and ACT datasets for 2017 and 2018
final = pd.merge(comb_18, comb_17, on = 'state')

# %%
# check on merge
final.head()
# Out:
#         state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1169
# 4  California                  0.60         540          536          1076
#
#    participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 0                  1.00         19.1        18.9         18.3         19.6
# 1                  0.33         20.8        19.8         20.6         21.6
# 2                  0.66         19.2        18.2         19.4         19.5
# 3                  1.00         19.4        19.1         18.9         19.7
# 4                  0.27         22.7        22.5         22.5         23.0
#
# ...

# %%
# check on merge
final.shape
# Out:
# (51, 21)

# %%
# save clean merged dataframe for 2018 and 2017 SAT and ACT datasets
final.to_csv('../working_data/final.csv', index = False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().T
# Out:
#                       count         mean        std     min       25%  \
# participation_sat_18   51.0     0.466275   0.380142    0.02     0.045
# erw_sat_18             51.0   567.294118  45.317676  497.00   535.000
# math_sat_18            51.0   557.254902  48.887562  480.00   521.500
# total_sat_18           51.0  1124.647059  93.843875  977.00  1062.500
# participation_act_18   51.0     0.616471   0.340810    0.07     0.285
# comp_act_18            51.0    21.498039   2.117686   17.70    19.950
# eng_act_18             51.0    20.988235   2.446356   16.60    19.100
# math_act_18            51.0    21.125490   2.035765   17.80    19.400
# read_act_18            51.0    22.033333   2.164132   18.00    20.450
# sci_act_18             51.0    21.341176   1.870206   17.90    19.850
# participation_sat_17   51.0     0.398039   0.352766    0.02     0.040
# erw_sat_17             51.0   569.117647  45.666901  482.00   533.500
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def std_dev(data):
    n = len(data)
    mean = sum(data) / n
    var = (sum((i - mean) ** 2 for i in data) / n)
    std_dev = var ** 0.5
    return std_dev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {col.name: std_dev(col) for col in [final[i] for i in final.columns if (final[i].dtype != 'O')]}

# %%
sd
# Out:
# {'participation_sat_18': 0.3763965409204987,
#  'erw_sat_18': 44.87118561762388,
#  'math_sat_18': 48.40589946919447,
#  'total_sat_18': 92.91928260369197,
#  'participation_act_18': 0.33745194881997503,
#  'comp_act_18': 2.0968220768561987,
#  'eng_act_18': 2.4222536143202795,
#  'math_act_18': 2.015707255555717,
#  'read_act_18': 2.14280983452291,
#  'sci_act_18': 1.851779903767018,
#  'participation_sat_17': 0.3492907076664507,
#  'erw_sat_17': 45.21697020437866,
#  'math_sat_17': 46.65713364485503,
#  'total_sat_17': 91.58351056778743,
#  'participation_act_17': 0.3182417575123181,
#  'eng_act_17': 2.3304876369363363,
#  'math_act_17': 1.9624620273436781,
#  'read_act_17': 2.0469029314842646,
#  'sci_act_17': 1.7222161451443676,
#  'comp_act_17': 2.000786081581989}

# %%
# check against ouput from pandas' describe()
final.describe()
# Out:
#        participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# count             51.000000   51.000000    51.000000     51.000000
# mean               0.466275  567.294118   557.254902   1124.647059
# std                0.380142   45.317676    48.887562     93.843875
# min                0.020000  497.000000   480.000000    977.000000
# 25%                0.045000  535.000000   521.500000   1062.500000
# 50%                0.520000  552.000000   547.000000   1099.000000
# 75%                0.795000  616.500000   600.500000   1220.000000
# max                1.000000  643.000000   655.000000   1298.000000
#
#        participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# count             51.000000    51.000000   51.000000    51.000000
# mean               0.616471    21.498039   20.988235    21.125490
# std                0.340810     2.117686    2.446356     2.035765
# min                0.070000    17.700000   16.600000    17.800000
# ...

# %%
# check against ouput from numpy's std()
np.std(final)
# Out:
# participation_sat_18     0.376397
# erw_sat_18              44.871186
# math_sat_18             48.405899
# total_sat_18            92.919283
# participation_act_18     0.337452
# comp_act_18              2.096822
# eng_act_18               2.422254
# math_act_18              2.015707
# read_act_18              2.142810
# sci_act_18               1.851780
# participation_sat_17     0.349291
# erw_sat_17              45.216970
# math_sat_17             46.657134
# total_sat_17            91.583511
# participation_act_17     0.318242
# eng_act_17               2.330488
# math_act_17              1.962462
# read_act_17              2.046903
# sci_act_17               1.722216
# comp_act_17              2.000786
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# When compared with standard deviation obtained using pandas describe function, there are decimal differences. Results of numpy standard deviation is the same as the one computed as per the formula just that numpy rounded to 6 decimal places.
#
# </font>

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# obtain summarry stats of dataset
final.describe()
# Out:
#        participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# count             51.000000   51.000000    51.000000     51.000000
# mean               0.466275  567.294118   557.254902   1124.647059
# std                0.380142   45.317676    48.887562     93.843875
# min                0.020000  497.000000   480.000000    977.000000
# 25%                0.045000  535.000000   521.500000   1062.500000
# 50%                0.520000  552.000000   547.000000   1099.000000
# 75%                0.795000  616.500000   600.500000   1220.000000
# max                1.000000  643.000000   655.000000   1298.000000
#
#        participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# count             51.000000    51.000000   51.000000    51.000000
# mean               0.616471    21.498039   20.988235    21.125490
# std                0.340810     2.117686    2.446356     2.035765
# min                0.070000    17.700000   16.600000    17.800000
# ...

# %%
# states with SAT participation rate in 2017 in the first quartile 
sat_part_low_17 = final[final['participation_sat_17'] < 0.04].sort_values('participation_sat_17')
sat_part_low_17
# Out:
#            state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 15          Iowa                  0.03         634          631          1265
# 24   Mississippi                  0.03         630          606          1236
# 34  North Dakota                  0.02         640          643          1283
# 3       Arkansas                  0.05         592          576          1169
# 23     Minnesota                  0.04         643          655          1298
# 25      Missouri                  0.04         633          629          1262
# 27      Nebraska                  0.03         629          623          1252
# 41  South Dakota                  0.03         622          618          1240
# 44          Utah                  0.04         618          612          1230
# 49     Wisconsin                  0.03         641          653          1294
# 50       Wyoming                  0.03         633          625          1257
#
# ...

# %% [markdown]
# Iowa, Mississippi and North Dakota has the lowest SAT participation rates in 2017. These states are among the 11 states that are in the first lower quartile of SAT participation rates in the US in 2017.

# %%
# states with SAT participation rate in 2017 above the third quartile 
sat_part_high_17 = final[final['participation_sat_17'] > 0.66].sort_values('participation_sat_17', ascending = False)
sat_part_high_17
# Out:
#                    state  participation_sat_18  erw_sat_18  math_sat_18  \
# 6            Connecticut                  1.00         535          519
# 7               Delaware                  1.00         505          492
# 8   District of Columbia                  0.92         497          480
# 22              Michigan                  1.00         511          499
# 29         New Hampshire                  0.96         535          528
# 19                 Maine                  0.99         512          501
# 12                 Idaho                  1.00         508          493
# 9                Florida                  0.97         522          493
# 21         Massachusetts                  0.80         562          563
# 39          Rhode Island                  0.97         513          505
# 30            New Jersey                  0.82         547          547
# 20              Maryland                  0.76         545          535
# ...

# %% [markdown]
# Connecticut, Delaware, District of Columbia and Michigan had 100% SAT participation rates in 2017. These states are among the 13 states that are in the top quartile of SAT participation rates in the US in 2017.

# %%
# states with SAT participation rate in 2018 in the first quartile 
sat_part_low_18 = final[final['participation_sat_18'] < 0.045].sort_values('participation_sat_18')
sat_part_low_18
# Out:
#            state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 34  North Dakota                  0.02         640          643          1283
# 15          Iowa                  0.03         634          631          1265
# 24   Mississippi                  0.03         630          606          1236
# 27      Nebraska                  0.03         629          623          1252
# 41  South Dakota                  0.03         622          618          1240
# 49     Wisconsin                  0.03         641          653          1294
# 50       Wyoming                  0.03         633          625          1257
# 16        Kansas                  0.04         633          631          1265
# 17      Kentucky                  0.04         630          618          1248
# 18     Louisiana                  0.04         615          595          1210
# 23     Minnesota                  0.04         643          655          1298
# ...

# %% [markdown]
# Iowa, Mississipi and North Dokata still remained having the lowest SAT participation rate in 2018.

# %%
# states with SAT participation rate in 2018 above the third quartile 
sat_part_high_18 = final[final['participation_sat_18'] > 0.795].sort_values('participation_sat_18', ascending = False)
sat_part_high_18
# Out:
#                    state  participation_sat_18  erw_sat_18  math_sat_18  \
# 5               Colorado                  1.00         519          506
# 6            Connecticut                  1.00         535          519
# 7               Delaware                  1.00         505          492
# 12                 Idaho                  1.00         508          493
# 22              Michigan                  1.00         511          499
# 13              Illinois                  0.99         513          506
# 19                 Maine                  0.99         512          501
# 9                Florida                  0.97         522          493
# 39          Rhode Island                  0.97         513          505
# 29         New Hampshire                  0.96         535          528
# 8   District of Columbia                  0.92         497          480
# 30            New Jersey                  0.82         547          547
# ...

# %% [markdown]
# Connecticut, Delaware, District of Columbia and Michigan remained in the top quartile range of SAT particiaption rates in 2018. Colorado and Idaho has in 2018 achieved 100% SAT participation rates.

# %%
# get summary stats for ACT participation in 2017
final['participation_act_17'].describe()
# Out:
# count    51.000000
# mean      0.652549
# std       0.321408
# min       0.080000
# 25%       0.310000
# 50%       0.690000
# 75%       1.000000
# max       1.000000
# Name: participation_act_17, dtype: float64

# %%
# states with ACT participation rates in 2017 within the first quartile 
act_part_low_17 = final[final['participation_act_17'] < 0.31].sort_values('participation_act_17')
act_part_low_17
# Out:
#             state  participation_sat_18  erw_sat_18  math_sat_18  \
# 19          Maine                  0.99         512          501
# 7        Delaware                  1.00         505          492
# 29  New Hampshire                  0.96         535          528
# 39   Rhode Island                  0.97         513          505
# 38   Pennsylvania                  0.70         547          539
# 20       Maryland                  0.76         545          535
# 21  Massachusetts                  0.80         562          563
# 22       Michigan                  1.00         511          499
# 45        Vermont                  0.64         565          554
# 46       Virginia                  0.68         567          550
# 47     Washington                  0.69         543          538
#
#     total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 19          1013                  0.07         24.0        23.8         23.6
# ...

# %% [markdown]
# Maine has the lowest ACT participation rate in 2017. Delaware and Michigan which had 100% SAT participation rate has very low ACT participation rates in 2017. These states are among the 11 states in the lower quartile range of ACT participation rates.

# %%
# states with ACT participation rates in 2017 above the third quartile 
act_part_high_17 = final[final['participation_act_17'] == 1].sort_values('participation_act_17', ascending = False)
act_part_high_17
# Out:
#              state  participation_sat_18  erw_sat_18  math_sat_18  \
# 0          Alabama                  0.06         595          571
# 28          Nevada                  0.23         574          566
# 49       Wisconsin                  0.03         641          653
# 44            Utah                  0.04         618          612
# 42       Tennessee                  0.06         624          607
# 40  South Carolina                  0.55         547          523
# 35        Oklahoma                  0.08         541          521
# 33  North Carolina                  0.52         554          543
# 26         Montana                  0.10         606          592
# 3         Arkansas                  0.05         592          576
# 25        Missouri                  0.04         633          629
# 24     Mississippi                  0.03         630          606
# 23       Minnesota                  0.04         643          655
# ...

# %% [markdown]
# These 17 states has 100% ACT participation rates in 2017. Wisconsin, Wyoming, Mississippi, Missouri are amongst the states here which also has very low SAT participation rates in 2017.

# %%
# get summary stats for ACT participation in 2018
final['participation_act_18'].describe()
# Out:
# count    51.000000
# mean      0.616471
# std       0.340810
# min       0.070000
# 25%       0.285000
# 50%       0.660000
# 75%       1.000000
# max       1.000000
# Name: participation_act_18, dtype: float64

# %%
# states with ACT participation rates in 2018 within the first quartile 
act_part_low_18 = final[final['participation_act_18'] < 0.285].sort_values('participation_act_18')
act_part_low_18
# Out:
#             state  participation_sat_18  erw_sat_18  math_sat_18  \
# 19          Maine                  0.99         512          501
# 39   Rhode Island                  0.97         513          505
# 29  New Hampshire                  0.96         535          528
# 7        Delaware                  1.00         505          492
# 38   Pennsylvania                  0.70         547          539
# 22       Michigan                  1.00         511          499
# 45        Vermont                  0.64         565          554
# 46       Virginia                  0.68         567          550
# 47     Washington                  0.69         543          538
# 21  Massachusetts                  0.80         562          563
# 6     Connecticut                  1.00         535          519
# 4      California                  0.60         540          536
# 32       New York                  0.79         534          534
#
# ...

# %% [markdown]
# Almost all of the states which were in the first quartile range of ACT participation rates in 2017 are still in the lower quartile in 2018.

# %%
# states with ACT participation rates in 2018 above the third quartile 
act_part_high_18 = final[final['participation_act_18'] == 1].sort_values('participation_act_18', ascending = False)
act_part_high_18
# Out:
#              state  participation_sat_18  erw_sat_18  math_sat_18  \
# 0          Alabama                  0.06         595          571
# 33  North Carolina                  0.52         554          543
# 49       Wisconsin                  0.03         641          653
# 44            Utah                  0.04         618          612
# 42       Tennessee                  0.06         624          607
# 40  South Carolina                  0.55         547          523
# 36            Ohio                  0.18         552          547
# 35        Oklahoma                  0.08         541          521
# 28          Nevada                  0.23         574          566
# 3         Arkansas                  0.05         592          576
# 27        Nebraska                  0.03         629          623
# 26         Montana                  0.10         606          592
# 25        Missouri                  0.04         633          629
# ...

# %% [markdown]
# These 17 states have 100% ACT participation rates in 2018 and most also have 100% participation rates in 2017. Only North and South Carolina had at least a 50% SAT participation rate, which the rest of the states had very low SAT participation rates.

# %%
# get summary stats for total SAT score in 2017
final['total_sat_17'].describe()
# Out:
# count      51.000000
# mean     1126.098039
# std        92.494812
# min       950.000000
# 25%      1055.500000
# 50%      1107.000000
# 75%      1212.000000
# max      1295.000000
# Name: total_sat_17, dtype: float64

# %%
# states with the lowest total score for SAT in 2017
sat_score_low_17 = final[final['total_sat_17'] < 1055].sort_values('total_sat_17')
sat_score_low_17
# Out:
#                    state  participation_sat_18  erw_sat_18  math_sat_18  \
# 8   District of Columbia                  0.92         497          480
# 7               Delaware                  1.00         505          492
# 12                 Idaho                  1.00         508          493
# 22              Michigan                  1.00         511          499
# 19                 Maine                  0.99         512          501
# 9                Florida                  0.97         522          493
# 43                 Texas                  0.66         520          512
# 6            Connecticut                  1.00         535          519
# 35              Oklahoma                  0.08         541          521
# 10               Georgia                  0.70         542          522
# 29         New Hampshire                  0.96         535          528
# 32              New York                  0.79         534          534
#
# ...

# %% [markdown]
# States like Michigan, Connecticut, Delaware and District of Columbia which had 100% SAT participation rates were among these states with the lowest SAT scores within the first quartile.

# %%
# states with higher total SAT scores in 2017, above the third quartile range 
sat_score_high_17 = final[final['total_sat_17'] > 1212].sort_values('total_sat_17', ascending = False)
sat_score_high_17
# Out:
#            state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 23     Minnesota                  0.04         643          655          1298
# 49     Wisconsin                  0.03         641          653          1294
# 15          Iowa                  0.03         634          631          1265
# 25      Missouri                  0.04         633          629          1262
# 16        Kansas                  0.04         633          631          1265
# 34  North Dakota                  0.02         640          643          1283
# 27      Nebraska                  0.03         629          623          1252
# 17      Kentucky                  0.04         630          618          1248
# 24   Mississippi                  0.03         630          606          1236
# 44          Utah                  0.04         618          612          1230
# 50       Wyoming                  0.03         633          625          1257
# ...

# %% [markdown]
# States with one of the lowest SAT participation rates in 2017 like Iowa, Mississippi and North Dakota, is among these states with the higher scores in the top quartile range.

# %%
# get summary stats on total SAT scores for 2018
final['total_sat_18'].describe()
# Out:
# count      51.000000
# mean     1124.647059
# std        93.843875
# min       977.000000
# 25%      1062.500000
# 50%      1099.000000
# 75%      1220.000000
# max      1298.000000
# Name: total_sat_18, dtype: float64

# %%
# states with the lowest total score (within the first quartile) for SAT in 2018
sat_score_low_18 = final[final['total_sat_18'] < 1062].sort_values('total_sat_18')
sat_score_low_18
# Out:
#                    state  participation_sat_18  erw_sat_18  math_sat_18  \
# 8   District of Columbia                  0.92         497          480
# 7               Delaware                  1.00         505          492
# 48         West Virginia                  0.28         513          486
# 12                 Idaho                  1.00         508          493
# 22              Michigan                  1.00         511          499
# 19                 Maine                  0.99         512          501
# 9                Florida                  0.97         522          493
# 39          Rhode Island                  0.97         513          505
# 13              Illinois                  0.99         513          506
# 5               Colorado                  1.00         519          506
# 43                 Texas                  0.66         520          512
# 6            Connecticut                  1.00         535          519
#
# ...

# %% [markdown]
# District of Columbia and Delaware remained the two states with the lowest SAT scores in 2017 and 2018. Most states which have low SAT scores in 2017 continue to remain in this quartile range.

# %%
# states with higher total SAT scores in 2018, above the third quartile range 
sat_score_high_18 = final[final['total_sat_18'] > 1220].sort_values('total_sat_18', ascending = False)
sat_score_high_18
# Out:
#            state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 23     Minnesota                  0.04         643          655          1298
# 49     Wisconsin                  0.03         641          653          1294
# 34  North Dakota                  0.02         640          643          1283
# 15          Iowa                  0.03         634          631          1265
# 16        Kansas                  0.04         633          631          1265
# 25      Missouri                  0.04         633          629          1262
# 50       Wyoming                  0.03         633          625          1257
# 27      Nebraska                  0.03         629          623          1252
# 17      Kentucky                  0.04         630          618          1248
# 41  South Dakota                  0.03         622          618          1240
# 24   Mississippi                  0.03         630          606          1236
# ...

# %% [markdown]
# Minnesota and Wisconsin remained the top 2 states with the highest SAT scores in 2017 and 2018.

# %%
# get summary stats for composite ACT score in 2017
final['comp_act_17'].describe()
# Out:
# count    51.000000
# mean     21.519608
# std       2.020695
# min      17.800000
# 25%      19.800000
# 50%      21.400000
# 75%      23.600000
# max      25.500000
# Name: comp_act_17, dtype: float64

# %%
# states with the lowest composite score (within the first quartile) for ACT in 2017
act_score_low_17 = final[final['comp_act_17'] < 19.8].sort_values('comp_act_17')
act_score_low_17
# Out:
#              state  participation_sat_18  erw_sat_18  math_sat_18  \
# 28          Nevada                  0.23         574          566
# 24     Mississippi                  0.03         630          606
# 40  South Carolina                  0.55         547          523
# 11          Hawaii                  0.56         550          549
# 33  North Carolina                  0.52         554          543
# 0          Alabama                  0.06         595          571
# 3         Arkansas                  0.05         592          576
# 35        Oklahoma                  0.08         541          521
# 18       Louisiana                  0.04         615          595
# 2          Arizona                  0.29         577          572
# 31      New Mexico                  0.16         552          540
#
#     total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 28          1140                  1.00         17.7        16.6         17.8
# ...

# %% [markdown]
# Nevada has the lowest composite score on the ACT in 2017. North and South Carolina and Mississippi were among the states in the lower quartile range of ACT composite score in 2017, also had high ACT participation rate.

# %%
# states with higher ACT composite score in 2017 above the third quartile range 
act_score_high_17 = final[final['comp_act_17'] > 23.6].sort_values('comp_act_17', ascending = False)
act_score_high_17
# Out:
#                    state  participation_sat_18  erw_sat_18  math_sat_18  \
# 29         New Hampshire                  0.96         535          528
# 21         Massachusetts                  0.80         562          563
# 6            Connecticut                  1.00         535          519
# 19                 Maine                  0.99         512          501
# 8   District of Columbia                  0.92         497          480
# 32              New York                  0.79         534          534
# 7               Delaware                  1.00         505          492
# 22              Michigan                  1.00         511          499
# 39          Rhode Island                  0.97         513          505
# 30            New Jersey                  0.82         547          547
# 46              Virginia                  0.68         567          550
# 38          Pennsylvania                  0.70         547          539
#
# ...

# %% [markdown]
# New Hampshire had the highest ACT composite score in 2017. Maine, Delaware and Michigan, which were states with the lowest ACT participation rate in 2017, were among these states with scores within the top quartile range.

# %%
# get summary stats for composite ACT score in 2018
final['comp_act_18'].describe()
# Out:
# count    51.000000
# mean     21.498039
# std       2.117686
# min      17.700000
# 25%      19.950000
# 50%      21.300000
# 75%      23.650000
# max      25.600000
# Name: comp_act_18, dtype: float64

# %%
# states with the lowest composite score (within the first quartile) for ACT in 2018
act_score_low_18 = final[final['comp_act_18'] < 19.95].sort_values('comp_act_18')
act_score_low_18
# Out:
#              state  participation_sat_18  erw_sat_18  math_sat_18  \
# 28          Nevada                  0.23         574          566
# 40  South Carolina                  0.55         547          523
# 24     Mississippi                  0.03         630          606
# 11          Hawaii                  0.56         550          549
# 0          Alabama                  0.06         595          571
# 33  North Carolina                  0.52         554          543
# 2          Arizona                  0.29         577          572
# 18       Louisiana                  0.04         615          595
# 35        Oklahoma                  0.08         541          521
# 3         Arkansas                  0.05         592          576
# 31      New Mexico                  0.16         552          540
# 42       Tennessee                  0.06         624          607
# 9          Florida                  0.97         522          493
#
# ...

# %% [markdown]
# Nevada has the lowest composite ACT score in 2018 and also in 2017. Most states which had low composite ACT score in 2017 also remained in the first quartile in 2018.

# %%
# states with higher ACT composite score in 2018 above the third quartile range 
act_score_high_18 = final[final['comp_act_18'] > 23.65].sort_values('comp_act_18', ascending = False)
act_score_high_18
# Out:
#             state  participation_sat_18  erw_sat_18  math_sat_18  \
# 6     Connecticut                  1.00         535          519
# 21  Massachusetts                  0.80         562          563
# 29  New Hampshire                  0.96         535          528
# 32       New York                  0.79         534          534
# 22       Michigan                  1.00         511          499
# 39   Rhode Island                  0.97         513          505
# 45        Vermont                  0.64         565          554
# 19          Maine                  0.99         512          501
# 5        Colorado                  1.00         519          506
# 13       Illinois                  0.99         513          506
# 46       Virginia                  0.68         567          550
# 7        Delaware                  1.00         505          492
# 30     New Jersey                  0.82         547          547
#
# ...

# %% [markdown]
# Connecticut, Massachusetts and New Hampshire remains the top 3 highest ACT composite score for both 2017 and 2018. Most states which were in the top quartile range in 2017 remained in this range in 2018.

# %%
# check for change in states with 100% participation rates Y-o-Y for SAT
final[(final['participation_sat_17'] == 1)]
# Out:
#                    state  participation_sat_18  erw_sat_18  math_sat_18  \
# 6            Connecticut                  1.00         535          519
# 7               Delaware                  1.00         505          492
# 8   District of Columbia                  0.92         497          480
# 22              Michigan                  1.00         511          499
#
#     total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 6           1053                  0.26         25.6        26.0         24.8
# 7            998                  0.17         23.8        23.7         23.1
# 8            977                  0.32         23.6        23.7         22.7
# 22          1011                  0.22         24.4        24.5         23.9
#
#     read_act_18  ...  participation_sat_17  erw_sat_17  math_sat_17  \
# 6          26.1  ...                   1.0         530          512
# 7          24.5  ...                   1.0         503          492
# ...

# %% [markdown]
# States with 100% SAT participation rate in 2017 also had 100% participation rates in 2018 except for District of Columbia which dropped to 92% SAT participation rate in 2018.

# %%
final[(final['participation_sat_18'] == 1)]
# Out:
#           state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 5      Colorado                   1.0         519          506          1025
# 6   Connecticut                   1.0         535          519          1053
# 7      Delaware                   1.0         505          492           998
# 12        Idaho                   1.0         508          493          1001
# 22     Michigan                   1.0         511          499          1011
#
#     participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 5                   0.30         23.9        23.9         23.2         24.4
# 6                   0.26         25.6        26.0         24.8         26.1
# 7                   0.17         23.8        23.7         23.1         24.5
# 12                  0.36         22.3        21.9         21.6         23.2
# 22                  0.22         24.4        24.5         23.9         24.7
#
# ...

# %% [markdown]
# Colorado only had 19% SAT participation rate in 2017 and in 2018 had 100% SAT participation rate. This is likely due to a policy change. More analysis can be done on the huge percentage change in SAT participation rate.
#
# Idaho had 93% SAT participation in 2017 and a 100% SAT participation rate in 2018.

# %%
# check for change in states with 100% participation rates Y-o-Y for ACT
final[(final['participation_act_17'] == 1)]
# Out:
#              state  participation_sat_18  erw_sat_18  math_sat_18  \
# 0          Alabama                  0.06         595          571
# 3         Arkansas                  0.05         592          576
# 5         Colorado                  1.00         519          506
# 17        Kentucky                  0.04         630          618
# 18       Louisiana                  0.04         615          595
# 23       Minnesota                  0.04         643          655
# 24     Mississippi                  0.03         630          606
# 25        Missouri                  0.04         633          629
# 26         Montana                  0.10         606          592
# 28          Nevada                  0.23         574          566
# 33  North Carolina                  0.52         554          543
# 35        Oklahoma                  0.08         541          521
# 40  South Carolina                  0.55         547          523
# ...

# %% [markdown]
# There are significantly more states with 100% ACT participation rates compared to SAT. All of these states have 99-100% ACT participation rates in 2017 and 2018 except for Colorado which dropped to 30% ACT participation rate.

# %%
# check if any states show >50% participation on SAT and ACT in 2017
final[(final['participation_act_17'] > 0.5) & (final['participation_sat_17'] > 0.5)]
# Out:
#       state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 9   Florida                  0.97         522          493          1014
# 10  Georgia                  0.70         542          522          1064
# 11   Hawaii                  0.56         550          549          1099
#
#     participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 9                   0.66         19.9        19.2         19.3         21.1
# 10                  0.53         21.4        20.9         20.7         22.1
# 11                  0.89         18.9        18.2         19.0         19.1
#
#     ...  participation_sat_17  erw_sat_17  math_sat_17  total_sat_17  \
# 9   ...                  0.83         520          497          1017
# 10  ...                  0.61         535          515          1050
# 11  ...                  0.55         544          541          1085
#
#     participation_act_17  eng_act_17  math_act_17  read_act_17  sci_act_17  \
# ...

# %%
final[(final['participation_act_18'] > 0.5) & (final['participation_sat_18'] > 0.5)]
# Out:
#              state  participation_sat_18  erw_sat_18  math_sat_18  \
# 9          Florida                  0.97         522          493
# 10         Georgia                  0.70         542          522
# 11          Hawaii                  0.56         550          549
# 33  North Carolina                  0.52         554          543
# 40  South Carolina                  0.55         547          523
#
#     total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 9           1014                  0.66         19.9        19.2         19.3
# 10          1064                  0.53         21.4        20.9         20.7
# 11          1099                  0.89         18.9        18.2         19.0
# 33          1098                  1.00         19.1        18.0         19.3
# 40          1070                  1.00         18.3        17.3         18.2
#
#     read_act_18  ...  participation_sat_17  erw_sat_17  math_sat_17  \
# ...

# %% [markdown]
# Only Florida, Georgia and Hawaii have relatively equal proportion of participation rates between SAT and ACT in both 2017 and 2018. North and South Carolina had relatively equal proportion of participation rates between SAT and ACT in 2018.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (14,12))
plt.title("Correlation between SAT and ACT participation rates and scores", fontsize = 14)
sns.heatmap(final.corr(), 
            annot = True,
           vmin = -1,
           vmax = 1);

# %% [markdown]
# - Mean scores on a particular section of a test are highly correlated (~ 0.9) with the mean scores of other sections of the the test and the total scores of the test.
# - Participation rate on a given test is moderately positively correlated with scores on the opposite test

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows = nrows, ncols = 2, figsize = (16,12)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], align = 'left', facecolor = 'midnightblue') # feel free to add more settings
        ax[i].set_title(list_of_titles[i], fontsize = 14)# Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i], fontsize = 12)
        ax[i].set_ylabel(list_of_ylabels[i], fontsize = 12)

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# plot participation rates for SAT & ACT
cols = ['participation_sat_17', 'participation_sat_18', 'participation_act_17', 'participation_act_18']
titles = ['2017 SAT Participation Rate Count', '2018 SAT Participation Rate Count', '2017 ACT Participation Rate Count', '2018 ACT Participation Rate Count']
xlabels = ['Participation Rate', 'Participation Rate', 'Participation Rate', 'Participation Rate']
ylabels = ['Participation Rate Count', 'Participation Rate Count', 'Participation Rate Count', 'Participation Rate Count']

subplot_histograms(final, cols, titles, xlabels, ylabels)

# %% [markdown]
# All histograms show a multimodal distribution with multiple peaks. The mode for SAT participation rate is at 0% participation rate. The second peak is at 60% participation rate in 2017 while in 2018, the second peak is at 100% participation rate. The mode for ACT participation rate is at 100% participation rate and second peak at 30% participation rate on both years.
#
# From 2017 to 2018, more states participated in the SAT as the count of 0% participation rate has reduced from about 21 to 18. The bar on 30% SAT participation rate in 2017 relates to Colorado which has moved to 100% participation rate in 2018 as the state made it a requirement to take the SAT from 2018 onwards. In 2018, there are more counts of 100% participation rate in 2018 than in 2017 signalling more states making SAT a requirement.
#
# Compared to SAT, more states offer ACT as seen in 100% participation rate counts to about 18 for both 2017 and 2018. On the other hand, the ACT's 100% participation rate count is 7 in 2017 and about 11 in 2018.

# %%
# plot math scores for SAT & ACT
cols = ['math_sat_17', 'math_sat_18', 'math_act_17', 'math_act_18']
titles = ['2017 SAT Math Score', '2018 SAT Math Score', '2017 ACT Math Score', '2018 ACT Math Score']
xlabels = ['Math Score', 'Math Score', 'Math Score', 'Math Score']
ylabels = ['Math Score Occurrence', 'Math Score Occurrence', 'Math Score Occurrence', 'Math Score Occurrence']

subplot_histograms(final, cols, titles, xlabels, ylabels)

# %% [markdown]
# All histograms show a multimodal distribution. The mode Math score on the SAT is at 525 in 2017 and improved in 2018 to about 540. For the ACT, mode Math score is at 19 for both years. However in 2018, more states recorded average Math score of 23.

# %%
final.head()
# Out:
#         state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1169
# 4  California                  0.60         540          536          1076
#
#    participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 0                  1.00         19.1        18.9         18.3         19.6
# 1                  0.33         20.8        19.8         20.6         21.6
# 2                  0.66         19.2        18.2         19.4         19.5
# 3                  1.00         19.4        19.1         18.9         19.7
# 4                  0.27         22.7        22.5         22.5         23.0
#
# ...

# %%
# plot reading/verbal scores for SAT & ACT
cols = ['erw_sat_17', 'erw_sat_18', 'read_act_17', 'read_act_18']
titles = ['2017 SAT Evidence-Based Reading and Writing Score', '2018 SAT Evidence-Based Reading and Writing Score', '2017 ACT Reading Score', '2018 ACT Reading Score']
xlabels = ['Scores', 'Scores', 'Scores', 'Scores']
ylabels = ["", "", "", ""]

subplot_histograms(final, cols, titles, xlabels, ylabels)

# %% [markdown]
# Histograms also show a multimodal distribution. The mode for SAT ERW score in 2017 is about 530 with a second peak at about 630, while in 2018, the mode improved to about 540 and it's second peak remained at about 630. The mode reading score for ACT remains the same across both years at about 20.5, which a second peak at about 24.5.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
final.head()
# Out:
#         state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1169
# 4  California                  0.60         540          536          1076
#
#    participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 0                  1.00         19.1        18.9         18.3         19.6
# 1                  0.33         20.8        19.8         20.6         21.6
# 2                  0.66         19.2        18.2         19.4         19.5
# 3                  1.00         19.4        19.1         18.9         19.7
# 4                  0.27         22.7        22.5         22.5         23.0
#
# ...

# %%
# function for scatterplots
def sns_scatter(x, y, title, xlabel, ylabel):
    plt.figure(figsize = (8,6))
    px = sns.scatterplot(data = final, x = x, y = y, hue = "state", legend = False, s = 50)
#     for line in range(0, final.shape[0]):
#         px.text(final_Y[x][line]+0.5, final_Y[y][line], final_Y['state'][line], horizontalalignment = 'left', size = 'medium', color = 'black')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
# SAT vs. ACT math scores for 2017
sns_scatter('math_act_17','math_sat_17','SAT vs ACT Math Scores 2017', 'ACT', 'SAT')

# %% [markdown]
# There is no clear trend in the scatter. We are unable to determine if states that score high in the ACT also scored high in the SAT.

# %%
# SAT vs. ACT verbal/reading scores for 2017
sns_scatter('read_act_17','erw_sat_17','SAT vs ACT Verbal/Reading Scores 2017', 'ACT', 'SAT')

# %% [markdown]
# There is also no clear trend in the scatter but compared to Math scores, there are no points in the lower quadrant (ie. score low on ACT scores and SAT score) and no points in the upper quadrant (ie. score high on ACT scores and SAT score)

# %%
# SAT vs. ACT total/composite scores for 2017
sns_scatter('comp_act_17','total_sat_17','SAT vs ACT Total/Composite Scores 2017', 'ACT', 'SAT')

# %% [markdown]
# A similar trend is observed for total and composite scores.

# %%
# Total scores for SAT 2017 vs 2018
sns_scatter('total_sat_17','total_sat_18','Total SAT Scores 2017 vs 2018', '2017', '2018')

# %% [markdown]
# There is a pretty linear relationship as total scores obtained in 2017 is likely to be maintained in 2018. This is except for a few outliers.

# %%
# Composite scores for ACT 2017 vs 2018
sns_scatter('comp_act_17','comp_act_18','Composite ACT Scores 2017 vs 2018', '2017', '2018')

# %% [markdown]
# There is also a relatively linear relationship for composite ACT scores, except for a few outliers as well.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
final.head()
# Out:
#         state  participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 0     Alabama                  0.06         595          571          1166
# 1      Alaska                  0.43         562          544          1106
# 2     Arizona                  0.29         577          572          1149
# 3    Arkansas                  0.05         592          576          1169
# 4  California                  0.60         540          536          1076
#
#    participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 0                  1.00         19.1        18.9         18.3         19.6
# 1                  0.33         20.8        19.8         20.6         21.6
# 2                  0.66         19.2        18.2         19.4         19.5
# 3                  1.00         19.4        19.1         18.9         19.7
# 4                  0.27         22.7        22.5         22.5         23.0
#
# ...

# %%
final.describe()
# Out:
#        participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# count             51.000000   51.000000    51.000000     51.000000
# mean               0.466275  567.294118   557.254902   1124.647059
# std                0.380142   45.317676    48.887562     93.843875
# min                0.020000  497.000000   480.000000    977.000000
# 25%                0.045000  535.000000   521.500000   1062.500000
# 50%                0.520000  552.000000   547.000000   1099.000000
# 75%                0.795000  616.500000   600.500000   1220.000000
# max                1.000000  643.000000   655.000000   1298.000000
#
#        participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# count             51.000000    51.000000   51.000000    51.000000
# mean               0.616471    21.498039   20.988235    21.125490
# std                0.340810     2.117686    2.446356     2.035765
# min                0.070000    17.700000   16.600000    17.800000
# ...

# %%
sat_section_scores = final[['state', 'erw_sat_17', 'erw_sat_18', 'math_sat_17', 'math_sat_18']]
sat_total_scores = final[['total_sat_17', 'total_sat_18']]
act_scores = final[['comp_act_18', 'eng_act_18', 'math_act_18', 'read_act_18', 'sci_act_18' ]]
part = final[['participation_sat_17', 'participation_sat_18', 'participation_act_17', 'participation_act_18']]

# %%
# box plot for participation rate
participation_rates = final.loc[:,['participation_sat_17','participation_sat_18','participation_act_17','participation_act_18']]
participation_rates = participation_rates.rename(columns={
    'participation_sat_17':'SAT 2017',
    'participation_sat_18':'SAT 2018',
    'participation_act_17':'ACT 2017',
    'participation_act_18':'ACT 2018'
})
plt.figure(figsize=(10,6))
plt.title('The Distribution of State ACT and SAT Participation Rates, 2017-18')
sns.boxplot(data=participation_rates,orient='h',palette='Set1');

# %% [markdown]
# Distribution of ACT participation rates across the 50 states are centered significantly higher than that of the SAT.

# %%
# box plot for sat subject scores
subj_sat = final.loc[:,['erw_sat_17','erw_sat_18','math_sat_17','math_sat_18']]
subj_sat = subj_sat.rename(columns={
    'erw_sat_17':'ERW SAT 2017',
    'erw_sat_18':'ERW SAT 2018',
    'math_sat_17':'MATH SAT 2017',
    'math_sat_18':'MATH SAT 2018'
})
plt.figure(figsize=(10,6))
plt.title('The Distribution of SAT Subject Scores, 2017-18')
sns.boxplot(data=subj_sat,orient='h',palette='Set2');

# %% [markdown]
# SAT Math scores in 2017 have larger spread than the rest while across all subjects, there are more scores above each subject's respective median by year.

# %%
# box plot for act subject scores
subj_act = final.loc[:,['eng_act_17','eng_act_18','math_act_17','math_act_18','read_act_17','read_act_18','sci_act_17','sci_act_18']]
subj_act = subj_act.rename(columns={
    'eng_act_17':'ENG ACT 2017',
    'eng_act_18':'ENG ACT 2018',
    'math_act_17':'MATH ACT 2017',
    'math_act_18':'MATH ACT 2018',
    'read_act_17':'READ ACT 2017',
    'read_act_18':'READ ACT 2018',
    'sci_act_17': 'SCI ACT 2017',
    'sci_act_18': 'SCI ACT 2018'    
})
plt.figure(figsize=(10,6))
plt.title('The Distribution of ACT Subject Scores, 2017-18')
sns.boxplot(data=subj_act,orient='h',palette='Set2');

# %% [markdown]
# ACT English score in 2017 has the widest spread compared to other subejcts. All subjects also have more states scoring above the 50% quartile range.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# reorganise dataframe to get test type as categorical 
state_part_act17 = final[['state', 'participation_act_17']]
state_part_act17['test_type'] = 'ACT17'
state_part_act17.rename(columns = {'participation_act_17': 'participation_rate'}, inplace = True)

state_part_act18 = final[['state', 'participation_act_18']]
state_part_act18['test_type'] = 'ACT18'
state_part_act18.rename(columns = {'participation_act_18': 'participation_rate'}, inplace = True)

state_part_sat17 = final[['state', 'participation_sat_17']]
state_part_sat17['test_type'] = 'SAT17'
state_part_sat17.rename(columns = {'participation_sat_17': 'participation_rate'}, inplace = True)

state_part_sat18 = final[['state', 'participation_sat_18']]
state_part_sat18['test_type'] = 'SAT18'
state_part_sat18.rename(columns = {'participation_sat_18': 'participation_rate'}, inplace = True)

# concatenate dataframe 
part_states_viz = pd.concat([state_part_act17, state_part_act18, state_part_sat17, state_part_sat18], ignore_index = True)
part_states_viz_sorted = part_states_viz.sort_values(by = ['state']).reset_index(drop = True)

#split into two for better visualization
part_states_viz_sorted1 = part_states_viz_sorted[:100]
part_states_viz_sorted2 = part_states_viz_sorted[100:]
# Out:
# /Users/zawanah/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/zawanah/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
# /Users/zawanah/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# visualize participation rate for both ACT and SAT by states
plt.figure(figsize = (26,5))
orders = ['ACT17', 'ACT18', 'SAT17', 'SAT18']
palette = {'ACT17': 'cornflowerblue', 'ACT18': 'royalblue', 'SAT17': 'darkseagreen', 'SAT18': 'g'}
sns.barplot(x = 'state', y = 'participation_rate', hue = 'test_type', hue_order = orders, palette = palette, data = part_states_viz_sorted1)
plt.xlabel('States', fontsize = 12)
plt.xticks(fontsize = 12, rotation = 30)
plt.ylabel('Participation Rate', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Participation Rate of SAT and ACT across States');

# %% [markdown]
# States generally lean towards either of the tests, ACT or SAT and not both. Colorado and Illinois show sharp increase in SAT participation rates in 2018 (alongside a drop in ACT participation rates).

# %%
plt.figure(figsize = (24,5))
orders = ['ACT17', 'ACT18', 'SAT17', 'SAT18']
palette = {'ACT17': 'cornflowerblue', 'ACT18': 'royalblue', 'SAT17': 'darkseagreen', 'SAT18': 'g'}
sns.barplot(x = 'state', y = 'participation_rate', hue = 'test_type', hue_order = orders, palette = palette, data = part_states_viz_sorted2)
plt.xlabel('States', fontsize = 12)
plt.xticks(fontsize = 12)
plt.ylabel('Participation Rate', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Participation Rate of SAT and ACT across States');

# %% [markdown]
# There are also states which do not show any preference, suggesting that these states do not mandate any particular tests, unlike some state policies.

# %%
# include median household income range in data
median_household_Y = pd.read_csv('../data/income_cat.csv') #obtained from census.gov
final_Y = pd.merge(median_household_Y,final, how = 'right')
final_Y.head()
# Out:
#         state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0     Alabama       <50K                  0.06         595          571
# 1      Alaska     >= 70K                  0.43         562          544
# 2     Arizona  55K - 60K                  0.29         577          572
# 3    Arkansas       <50K                  0.05         592          576
# 4  California     >= 70K                  0.60         540          536
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1166                  1.00         19.1        18.9         18.3
# 1          1106                  0.33         20.8        19.8         20.6
# 2          1149                  0.66         19.2        18.2         19.4
# 3          1169                  1.00         19.4        19.1         18.9
# 4          1076                  0.27         22.7        22.5         22.5
#
#    ...  participation_sat_17  erw_sat_17  math_sat_17  total_sat_17  \
# ...

# %%
# check if income and participation is correlated
order = ['>= 70K', '60K - 70K','55K - 60K', '50K - 55K', '<50K']
plt.figure(figsize = (12,10))
sns.scatterplot(data = final_Y, x = 'participation_sat_18', y = 'participation_act_18', hue = 'income_cat', hue_order = order, ci = None, s = 80)
plt.show();

# %% [markdown]
# Generally, lower income categories (<55K) participate in ACT than SAT.

# %%
# check if income, scores and participation are correlated
order = ['>= 70K', '60K - 70K','55K - 60K', '50K - 55K', '<50K']
plt.figure(figsize = (12,10))
sns.scatterplot(data = final_Y, x = 'total_sat_18', y = 'participation_sat_18', hue = 'income_cat', s = 80, hue_order = order, ci = None)
# for line in range(0, final_Y.shape[0]):
#     p1.text(final_Y['total_sat_18'][line]+0.5, final_Y['participation_sat_18'][line], final_Y['state'][line], horizontalalignment = 'left', size = 'medium', color = 'black')
plt.xlabel('Total SAT Score in 2018', fontsize = 12)
plt.xticks(fontsize = 12)
plt.ylabel('SAT Participation Rate in 2018', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Participation Rate against Total SAT Score in 2018 across States')
plt.show();

# %% [markdown]
# States with lower participation rates tend to score higher in the SATs. Also, states that belong to the lower income category which have lower participation rates tend to score higher. Overall there is a general inverse relationship between SAT score and participation rate.

# %%
# cehck if states offer free SAT vs those who do not, have a correlation with participation rate
final_Y['free_test'] = ""
for index,row in final_Y.iterrows():
    free_test = ['Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 'Ohio', 'Oklahoma', 'Rhode Island', 'South Carolina', 'Tennessee', 'West Virginia']
    if final_Y.at[index, 'state'] in free_test:
        final_Y.at[index, 'free_test'] = 1
    else:
        final_Y.at[index, 'free_test'] = 0

final_Y.head()
# Out:
#         state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0     Alabama       <50K                  0.06         595          571
# 1      Alaska     >= 70K                  0.43         562          544
# 2     Arizona  55K - 60K                  0.29         577          572
# 3    Arkansas       <50K                  0.05         592          576
# 4  California     >= 70K                  0.60         540          536
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1166                  1.00         19.1        18.9         18.3
# 1          1106                  0.33         20.8        19.8         20.6
# 2          1149                  0.66         19.2        18.2         19.4
# 3          1169                  1.00         19.4        19.1         18.9
# 4          1076                  0.27         22.7        22.5         22.5
#
#    ...  erw_sat_17  math_sat_17  total_sat_17  participation_act_17  \
# ...

# %%
# plot to check if free test contributes to higher scroes
plt.figure(figsize = (12,10))
sns.scatterplot(data = final_Y, x = 'total_sat_18', y = 'participation_sat_18', hue = 'free_test', s = 80, ci = None);
# for line in range(0, final_Y.shape[0]):
#     p3.text(final_Y['total_sat_18'][line]+0.5, final_Y['participation_sat_18'][line], final_Y['state'][line], horizontalalignment = 'left', size = 'medium', color = 'black')
plt.xlabel('Total SAT Score in 2018', fontsize = 12)
plt.xticks(fontsize = 12)
plt.ylabel('SAT Participation Rate in 2018', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Participation Rate against Total SAT Score in 2018 across States')
plt.legend(title = 'Free College Admission Test', labels = ['No', 'Yes'])
plt.show();

# %% [markdown]
# 90-100% participation rates for states who offer free SAT tests. Tennessee scored the highest amongst states which provide free SAT tests.

# %%
# cehck if states offer free college admission vs those who do not, have a correlation with participation rate
final_Y['free_college'] = ""
for index,row in final_Y.iterrows():
    free_college = ['Arkansas', 'California', 'Delaware', 'Hawaii', 'Indiana', 'Kentucky', 'Maryland', 'Minnesota', 'Missouri', 'Montana', 'New York', 'Nevada', 'Oklahoma','Oregon', 'Rhode Island', 'Tennessee', 'Washington']
    if final_Y.at[index, 'state'] in free_college:
        final_Y.at[index, 'free_college'] = 1
    else:
        final_Y.at[index, 'free_college'] = 0

final_Y.head()
# Out:
#         state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0     Alabama       <50K                  0.06         595          571
# 1      Alaska     >= 70K                  0.43         562          544
# 2     Arizona  55K - 60K                  0.29         577          572
# 3    Arkansas       <50K                  0.05         592          576
# 4  California     >= 70K                  0.60         540          536
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1166                  1.00         19.1        18.9         18.3
# 1          1106                  0.33         20.8        19.8         20.6
# 2          1149                  0.66         19.2        18.2         19.4
# 3          1169                  1.00         19.4        19.1         18.9
# 4          1076                  0.27         22.7        22.5         22.5
#
#    ...  math_sat_17  total_sat_17  participation_act_17  eng_act_17  \
# ...

# %%
# OTHER EXPLORATORY PLOTS 
# plot to check if free college programs contributes to higher scroes/ participation
plt.figure(figsize = (12,10))
p4 = sns.scatterplot(data = final_Y, x = 'total_sat_18', y = 'participation_sat_18', hue = 'free_college', s = 80, ci = None)
for line in range(0, final_Y.shape[0]):
    p4.text(final_Y['total_sat_18'][line]+0.5, final_Y['participation_sat_18'][line], final_Y['state'][line], horizontalalignment = 'left', size = 'medium', color = 'black')

plt.show();

# %% [markdown]
# There is no particular trend.

# %%
# OTHER EXPLORATORY PLOTS
# check if political leaning affects 
final_Y['pol'] = ""
for index,row in final_Y.iterrows():
    cons = ['Arizona', 'Arkansas','Montana', 'Idaho', 'Wyoming','Utah','Alaska','Texas','Oklahoma','Kansas','Nebraska','North Dakota','South Dakota','Iowa','Missouri','Louisiana', 'Mississippi','Alabama', 'Tennessee','Florida','North Carolina','South Carolina','Kentucky','Indiana','Ohio','West Virginia','Maine']
    if final_Y.at[index, 'state'] in cons:
        final_Y.at[index, 'pol'] = 1
    else:
        final_Y.at[index, 'pol'] = 0

final_Y.head()
# Out:
#         state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0     Alabama       <50K                  0.06         595          571
# 1      Alaska     >= 70K                  0.43         562          544
# 2     Arizona  55K - 60K                  0.29         577          572
# 3    Arkansas       <50K                  0.05         592          576
# 4  California     >= 70K                  0.60         540          536
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1166                  1.00         19.1        18.9         18.3
# 1          1106                  0.33         20.8        19.8         20.6
# 2          1149                  0.66         19.2        18.2         19.4
# 3          1169                  1.00         19.4        19.1         18.9
# 4          1076                  0.27         22.7        22.5         22.5
#
#    ...  participation_act_17  eng_act_17  math_act_17  read_act_17  \
# ...

# %%
# plot political leanings and sat scores 
plt.figure(figsize = (12,10))
sns.scatterplot(data = final_Y, x = 'total_sat_18', y = 'participation_sat_18', hue = 'pol', s = 80, ci = None);

# %% [markdown]
# Republican leaning states generally have lower SAT participation rates.

# %%
# OTHER EXPLORATORY PLOTS
# check by state industry (preference for trade/vocation schools)
final_Y['ind'] = ""
for index,row in final_Y.iterrows():
    auto = ['Alabama', 'Delaware', 'Indiana', 'Michigan', 'Missouri', 'Ohio', 'South Carolina']
    fish = ['Alaska', 'Maine']
    machine = ['Arizona', 'California', 'Florida', 'Idaho', 'Illinois', 'New Hampshire', 'New Mexico', 'Oklahoma','Oregon','Vermont','Virginia','Wisconsin']
    aero = ['Arkansas', 'Connecticut', 'Georgia', 'Hawaii', 'Kansas', 'Kentucky', 'Maryland','Washington']
    meat = ['Colorado', 'Iowa', 'Nebraska', 'South Dakota']
    mineral = ['Louisiana', 'Mississipi', 'Montana', 'North Dakota', 'Pennsylvania', 'Texas','West Virginia']
    preci = ['Minnesota', 'Tennessee']
    accom = ['Nevada']
    metal = ['New Jersey', 'New York', 'Rhode Island', 'Utah']
    med = ['North Carolina']
    chem = ['Wyoming']
    if final_Y.at[index, 'state'] in auto:
        final_Y.at[index, 'ind'] = 'Automotive'
    elif final_Y.at[index, 'state'] in fish:
        final_Y.at[index, 'ind'] = 'Fishing'
    elif final_Y.at[index, 'state'] in machine:
        final_Y.at[index, 'ind'] = 'Machinery'      
    elif final_Y.at[index, 'state'] in aero:
        final_Y.at[index, 'ind'] = 'Aerospace'
    elif final_Y.at[index, 'state'] in meat:
        final_Y.at[index, 'ind'] = 'Meat'
    elif final_Y.at[index, 'state'] in mineral:
        final_Y.at[index, 'ind'] = 'Mineral'
    elif final_Y.at[index, 'state'] in preci:
        final_Y.at[index, 'ind'] = 'Precision Instruments'
    elif final_Y.at[index, 'state'] in accom:
        final_Y.at[index, 'ind'] = 'Accommodation and Food'
    elif final_Y.at[index, 'state'] in metal:
        final_Y.at[index, 'ind'] = 'Precious Metals'
    elif final_Y.at[index, 'state'] in med:
        final_Y.at[index, 'ind'] = 'Medical'
    else:
        final_Y.at[index, 'ind'] = 'Chemicals'

final_Y.head()
# Out:
#         state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0     Alabama       <50K                  0.06         595          571
# 1      Alaska     >= 70K                  0.43         562          544
# 2     Arizona  55K - 60K                  0.29         577          572
# 3    Arkansas       <50K                  0.05         592          576
# 4  California     >= 70K                  0.60         540          536
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1166                  1.00         19.1        18.9         18.3
# 1          1106                  0.33         20.8        19.8         20.6
# 2          1149                  0.66         19.2        18.2         19.4
# 3          1169                  1.00         19.4        19.1         18.9
# 4          1076                  0.27         22.7        22.5         22.5
#
#    ...  eng_act_17  math_act_17  read_act_17  sci_act_17  comp_act_17  \
# ...

# %%
# OTHER EXPLORATORY PLOTS
# plot state industry and sat scores 
plt.figure(figsize = (12,10))
sns.scatterplot(data = final_Y, x = 'total_sat_18', y = 'participation_sat_18', hue = 'ind', s = 80, ci = None);

# %% [markdown]
# No clear trend between state industries.

# %%
# check if states with more funding in 2018 have an impact
final_Y['fund'] = ""
for index,row in final_Y.iterrows():
    more_fund = ['Florida', 'Georgia','Alabama', 'Tennessee', 'Louisiana','District of Columbia','Vermont','New Hampshire','Rhode Island','Michigan','Wisconsin','Minnesota','California','Nevada','Utah','Colorado', 'Oregon','Idaho', 'Hawaii']
    if final_Y.at[index, 'state'] in more_fund:
        final_Y.at[index, 'fund'] = 1
    else:
        final_Y.at[index, 'fund'] = 0

final_Y.head()
# Out:
#         state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0     Alabama       <50K                  0.06         595          571
# 1      Alaska     >= 70K                  0.43         562          544
# 2     Arizona  55K - 60K                  0.29         577          572
# 3    Arkansas       <50K                  0.05         592          576
# 4  California     >= 70K                  0.60         540          536
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1166                  1.00         19.1        18.9         18.3
# 1          1106                  0.33         20.8        19.8         20.6
# 2          1149                  0.66         19.2        18.2         19.4
# 3          1169                  1.00         19.4        19.1         18.9
# 4          1076                  0.27         22.7        22.5         22.5
#
#    ...  math_act_17  read_act_17  sci_act_17  comp_act_17  free_test  \
# ...

# %%
# OTHER EXPLORATORY PLOTS
# check if states with more funding in 2018 have an impact
plt.figure(figsize = (12,10))
p7 = sns.scatterplot(data = final_Y, x = 'total_sat_18', y = 'participation_sat_18', hue = 'fund', s = 80, ci = None)
# for line in range(0, final_Y.shape[0]):
#     p6.text(final_Y['total_sat_18'][line]+0.5, final_Y['participation_sat_18'][line], final_Y['state'][line], horizontalalignment = 'left', size = 'medium', color = 'black')

plt.show();

# %%
# OTHER EXPLORATORY PLOTS
# cehck if states require either
final_Y['must'] = ""
for index,row in final_Y.iterrows():
    must_ACT = ['Alabama', 'Hawaii', 'Idaho', 'Kentucky', 'Louisiana', 'Mississipi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'North Carolina', 'North Dakota', 'Ohio', 'South Carolina', 'Tennessee', 'Utah', 'Wisconsin', ' Wyoming']
    must_SAT = ['Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 'Ohio','Tennessee' ]
    if final_Y.at[index, 'state'] in must_ACT:
        final_Y.at[index, 'must'] = 0
    elif final_Y.at[index,'state'] in must_SAT:
        final_Y.at[index, 'must'] = 1        
    else:
        final_Y.at[index, 'must'] = 2

final_Y.tail()
# Out:
#             state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 46       Virginia     >= 70K                  0.68         567          550
# 47     Washington     >= 70K                  0.69         543          538
# 48  West Virginia       <50K                  0.28         513          486
# 49      Wisconsin  60K - 70K                  0.03         641          653
# 50        Wyoming  60K - 70K                  0.03         633          625
#
#     total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 46          1117                  0.24         23.9        23.8         23.3
# 47          1081                  0.24         22.2        21.4         22.2
# 48           999                  0.65         20.3        19.8         19.4
# 49          1294                  1.00         20.5        19.8         20.3
# 50          1257                  1.00         20.0        19.0         19.7
#
# ...

# %%
# get states with low part rate and don't require either
states_interest = final_Y[(final_Y['must'] == 2) & (final_Y['participation_sat_18'] < 0.2)]
states_interest
# Out:
#            state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 3       Arkansas       <50K                  0.05         592          576
# 15          Iowa  55K - 60K                  0.03         634          631
# 16        Kansas  55K - 60K                  0.04         633          631
# 23     Minnesota     >= 70K                  0.04         643          655
# 24   Mississippi       <50K                  0.03         630          606
# 31    New Mexico       <50K                  0.16         552          540
# 36      Oklahoma  50K - 55K                  0.08         541          521
# 41  South Dakota  55K - 60K                  0.03         622          618
# 50       Wyoming  60K - 70K                  0.03         633          625
#
#     total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 3           1169                  1.00         19.4        19.1         18.9
# ...

# %%
# OTHER EXPLORATORY PLOTS
# plot participation rates according to those required or not
plt.figure(figsize = (10,8))
palette = ['cornflowerblue', 'green','maroon']
p6 = sns.scatterplot(data = final_Y, x = 'participation_act_18', y = 'participation_sat_18', palette = palette, hue = 'must', s = 80, ci = None)
# for line in range(0, final_Y.shape[0]):
#     p6.text(final_Y['participation_act_18'][line]+0.1, final_Y['participation_sat_18'][line], final_Y['state'][line], horizontalalignment = 'left', size = 'medium', color = 'black')
plt.xlabel('ACT Participation Rate in 2018', fontsize = 12)
plt.xticks(fontsize = 12)
plt.ylabel('SAT Participation Rate in 2018', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Participation Rate of SAT and ACT across States');
# plt.legend(title = 'Legend', labels = ['ACT Required', 'SAT Required', 'None Required'])
leg = p6.get_legend()
leg.set_title("Test Requirement")
legtext = leg.texts
legtext[0].set_text("")
legtext[1].set_text("ACT Required")
legtext[2].set_text("SAT Required")
legtext[3].set_text("None Required")
plt.show();

# %%
popndf = pd.DataFrame.from_dict({'state': ['Arkansas', 'Iowa', 'Kansas', 'Minnesota', 'Mississippi', 'New Mexico', 'Oklahoma', 'South Dakota', 'Wyoming'],
                                 'popn': [31126, 35471, 35398, 61766, 29788, 20478, 41753, 8703, 5820]})

# %%
states_interest_pop = pd.merge(states_interest, popndf, how = 'left')
states_interest_pop
# Out:
#           state income_cat  participation_sat_18  erw_sat_18  math_sat_18  \
# 0      Arkansas       <50K                  0.05         592          576
# 1          Iowa  55K - 60K                  0.03         634          631
# 2        Kansas  55K - 60K                  0.04         633          631
# 3     Minnesota     >= 70K                  0.04         643          655
# 4   Mississippi       <50K                  0.03         630          606
# 5    New Mexico       <50K                  0.16         552          540
# 6      Oklahoma  50K - 55K                  0.08         541          521
# 7  South Dakota  55K - 60K                  0.03         622          618
# 8       Wyoming  60K - 70K                  0.03         633          625
#
#    total_sat_18  participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# 0          1169                  1.00         19.4        19.1         18.9
# ...

# %%
# OTHER EXPLORATORY PLOTS
# visualize participation rate for both ACT and SAT by states
plt.figure(figsize = (12,10))
sns.barplot(x = 'state', y = 'popn', color = 'midnightblue', data = states_interest_pop.sort_values('popn'))
plt.xlabel('States', fontsize = 12)
plt.xticks(fontsize = 12)
plt.ylabel('Number of High School Graduates', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Population of High School Graduates in 2018 by State');

# %%
# OTHER EXPLORATORY PLOTS
# plot participation rates according to those required or not
plt.figure(figsize = (10,8))
sns.scatterplot(data = final_Y, x = 'participation_act_18', y = 'participation_sat_18', s = 80, ci = None)
plt.xlabel('ACT Participation Rate in 2018', fontsize = 12)
plt.xticks(fontsize = 12)
plt.ylabel('SAT Participation Rate in 2018', fontsize = 12)
plt.yticks(fontsize = 12)
plt.title('Participation Rate of SAT and ACT across States');

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
# Out:
#        participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# count             51.000000   51.000000    51.000000     51.000000
# mean               0.466275  567.294118   557.254902   1124.647059
# std                0.380142   45.317676    48.887562     93.843875
# min                0.020000  497.000000   480.000000    977.000000
# 25%                0.045000  535.000000   521.500000   1062.500000
# 50%                0.520000  552.000000   547.000000   1099.000000
# 75%                0.795000  616.500000   600.500000   1220.000000
# max                1.000000  643.000000   655.000000   1298.000000
#
#        participation_act_18  comp_act_18  eng_act_18  math_act_18  \
# count             51.000000    51.000000   51.000000    51.000000
# mean               0.616471    21.498039   20.988235    21.125490
# std                0.340810     2.117686    2.446356     2.035765
# min                0.070000    17.700000   16.600000    17.800000
# ...

# %%
final.mode(numeric_only = True)
# Out:
#    participation_sat_18  erw_sat_18  math_sat_18  total_sat_18  \
# 0                  0.03       513.0          493        1086.0
# 1                  0.04       547.0          506        1099.0
# 2                   NaN       633.0          539        1117.0
# 3                   NaN         NaN          547        1265.0
# 4                   NaN         NaN          618           NaN
# 5                   NaN         NaN          631           NaN
#
#    participation_act_18  comp_act_18  eng_act_18  math_act_18  read_act_18  \
# 0                   1.0         20.0        18.2         19.7         24.7
# 1                   NaN         20.3        19.8         20.3          NaN
# 2                   NaN         23.9        23.8         23.6          NaN
# 3                   NaN          NaN         NaN          NaN          NaN
# 4                   NaN          NaN         NaN          NaN          NaN
# ...

# %% [markdown]
# Answers:
#
# SAT participation rate in 2018 follow a multimodal distribution with three peaks. Its mode is at 3-4% participation rate. Its second peak at 100% participation rate and the third at 6-7%. The mean participation rate is 47% while the median is 52% (ie 50% quartile).
#
# ERW SAT scores in 2018 also follow a multimodal distribution with three peaks. Its mode score is 547, second peak at 633, and third peak at 513. The mean score is 567 while median score is 552.
#
# Math SAT scores in 2018 follows a multimodal distribution. Its mode is 539 with other peaks at about 506 and 618-631. The mean score is 557 and median score is 547.
#
# Total SAT scores in 2018 follows a multimodal distribution. Its mode is at 1,117 and other peaks at 1,265, 1,099 and 1,086. The mean score is 1,124 and the median score is 1,099.
#
# ACT participation rate in 2018 follows a multimodal distribution. Its mode is at 100% and other smaller peaks at 30% and about 60%. The mean is 60% and the median is 66%.
#
# Composite ACT score in 2018 follows a bimodal distribution. Its mode is at 20 and second peak at 23. The mean score is 21.5 and the median score is 21.3.
#
# English ACT score in 2018 follows a bimodal distribution. Its mode is at 19 and second peak at 23. The mean score is 21 and the median score is 20.2.
#
# Math ACT score in 2018 follows a bimodal distribution. Its mode is at 19 and second peak at 23. The mean score is 21.1 and the median score is 20.2.
#
# Reading ACT score in 2018 follows a multimodal distribution. Its mode is at 21 and second peak at 24.7. The mean score is 22.0 and the median score is 21.7.
#
# Science ACT score in 2018 follows a multimodal distribution. Its mode is at 20 and second peak at 23. The mean score is 21.3 and the median score is 21.1.

# %%
plt.hist(final['sci_act_17'])
plt.xlabel("Scores")
plt.title("Science ACT Score 2017");

# %% [markdown]
# SAT participation rate in 2017 follow a multimodal distribution with three peaks. Its mode is at 3% participation rate. Its second peak at about 60% participation rate and the third at 100%. The mean participation rate is 40% while the median is 38% (ie 50% quartile).
#
# ERW SAT scores in 2017 also follow a bimodal distribution with three peaks. Its mode score is 530 and second peak at about 640. The mean score is 569 while median score is 559.
#
# Math SAT scores in 2017 follows a bimodal distribution. Its mode is 524 with other peak at about 600-625. The mean score is 557 and median score is 548.
#
# Total SAT scores in 2017 follows a bimodal distribution. Its mode is at 1,117 and other peak at about 1,250. The mean score is 1,126 and the median score is 1,107.
#
# ACT participation rate in 2017 follows a multimodal distribution. Its mode is at 100% and other smaller peaks at 30% and about 70%. The mean is 65% and the median is 70%.
#
# Composite ACT score in 2017 follows a multimodal distribution. Its mode is at 20 and other peaks at 22 and about 24. The mean score is 21.5 and the median score is 21.4.
#
# English ACT score in 2017 follows a multimodal distribution. Its mode is at 19 and other peaks at 21 and 24. The mean score is 20.9 and the median score is 20.7.
#
# Math ACT score in 2017 follows a multimodal distribution. Its mode is at 19 and other peaks at 21 and 23. The mean score is 21.2 and the median score is 20.9.
#
# Reading ACT score in 2017 follows a multimodal distribution. Its mode is at 20.8 and other peaks at 22.5 and 25. The mean score is 22 and the median score is 21.8.
#
# Science ACT score in 2017 follows a multimodal distribution. Its mode is at 22 and other peaks at 23 and 20. The mean score is 21.4 and the median score is 21.3.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# No.
# </font>

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# No the assumptions doesn't hold. From description of distribution above, data for Math, Reading score and Rates follow a multimodal distribution.
# </font>

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# It would not make sense to conduct statistical inference since the data is not normally distributed. We do not have data relating to the exact population for each states and number of students taking the SAT tests so participation rates may not be comparable across states. (eg. a 30% participation rate in a state with smaller population could be equivalent to a 10% participation rate in a state with larger population)
# </font>

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# <font color='darkblue'>
# It is not completely inappropriate to compare. Although the scores test on Math, the nature and focus of both tests are slightly different(Montgomery, 2019). Nevertheless, to a small extent, it gives an indication of understanding of basic concepts of Math.
#
# Source:
# https://blog.prepscholar.com/sat-math-vs-act-math-whats-the-difference
# </font>

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# <font color='darkblue'>
#
# <u>1. Colorado</u>
#
# Colorado showed a dramatic increase in SAT participation in 2018 compared to 2017. This is because the state voted to adopt SAT as the required test and 2018 would be the first year students take the SAT. The change is because the redesigned SAT measures skills and knowledge like critical thinking and analytical reasoning that are critical for college and career readiness.(Colorado Children's Campaign, 2016).
#
# As 2018 was the first year that Colorado students take the SAT, it did not as well as other states which have taken the SAT in previous years. A similar trend is seen with Illinois.
#
# <u>2. Tennessee</u>
#
# Tennessee is one of the states with very low participation rate in SAT but scored very high. One of the concerns with choosing to attend college is the tuition cost. To partly alleviate the financial burden, some states administer the SATs for free. From the analysis above, Tennessee scored the highest among other states that provide free SAT tests.
#
# Tennessee has a free-college program, called Tennessee Promise, which offers two years of tuition-free community college to all, regardless of income, since 2014 (Wermund, 2019). This helped bridged income gaps and made education accessible for all regardless of socio-economic background. (The Future of Education in Tennessee, 2020).
#
# <u>3. Alabama</u>
#
# State belongs to one of the lower income categories but have achieved high SAT scores, in spite of low participation rate. The State prioritises education. It has a First Class Pre-K program which was nationally recognised for its high quality every year and education employees received a 2.5% raise (Crain, 2019).
#
# Even with state support, there is low SAT participation rates. With a huge budget, offering state-funded SAT tests or free college programs could encourage more participation.
#
# </font>

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# <font color='darkblue'>
#
# <u>Alabama</u>
#
# Alabama is one of the states with low SAT participation rates and the median household income of the state is relatively low. In spite of those factors, the students who took the SAT in 2018 scored very well.
#
# Tuition cost is a huge consideration when it comes to deciding to attend college (Martin, 2018). Following from Tennessee's model, the College Board could consider the following :
#
#
# *State Partnership*
#
# Form a state partnership with Alabama to adopt SAT School Day which provides free SAT tests for high school students. This would remove cost as a barrier for paticipating in the SATs, which may be a huge concern for students who are not as well to do. Making it state-wide also reinforces how the State values importance of education for all.
#
# *Maintain Outreach to Students*
#
# Students may feel unprepared for college (Leal, 2015) so more support would be better for them to be convinced that college is achievable.
#
# *Reach out to Colleges*
#
# Encourage colleges to provide free college programs like Tennessee. Leverage on Colorado and Illinois' choices to promote SAT and emphasise value of recently redesigned tests, which make students more college ready. With more State support, this would help alleviate a huge financial burden on the students of Alabama.
#
#
#
#
#
# </font>
